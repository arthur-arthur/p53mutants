# %%
seed = 123

# %%
# import helper functions
from shutil import copyfile

copyfile(
    src = "/kaggle/input/bdc-p53/p53_helper_functions.py", 
    dst = "/kaggle/working/p53_helpers.py"
)

from p53_helpers import *
# Out:
# Using TensorFlow backend.

# %%
# load p53 ds (missing values removed)
X, Y = load_p53_ds()
    
# 80/20 stratified split
X_train, X_test, Y_train, Y_test = split_p53(X, Y)
# Out:
# Import completed after 4.4 sec
#
# CLASS RATIOS
# ================================================================================
# Training set active classes:   121/24927 (0.485 %)
# Test set active classes:       30/6232 (0.481 %)
#
# MATRIX DIMENSIONS
# ================================================================================
# TRAINING SET
# . Features:   (24927, 5408)
# . Classes:    (24927,)
# TEST SET
# . Features:   (6232, 5408)
# . Classes:    (6232,)

# %% [markdown]
# # Iterate
#
# To evaluate the different pre-processing steps, we iterate over different algorithms and hyperparameters, more specifically:
#
# * Remove most strongly correlated features
#     * n_remove
# * Center/scale
#     * no scaling, StandardScaler, RobustScaler
# * Univariate feature selection
#     * F/MIC
#     * k features
# * Model-based feature selection
#     * Linear/non-linear (non-LRC) models
#     * m features
# * Add principal components
#     * n
#
# 4-fold CV is performed and the mean train and validation fold metrics (MCC and balanced accuracy) are collected for all conditions to jointly evaluate the best-performing combinations. Note: transformations are performed on the entire trainin/validation set prior to CV partitioning to speed up the iterations. Hence, validation fold performance might be expected to be a slight overestimation, proper evalution and hyperparameter optimization will be performed later.

# %%
# downsample majority class to speed up iterations
DS = RandomUnderSampler(sampling_strategy=0.01)
X_train, Y_train = DS.fit_resample(X_train, Y_train)

print(X_train.shape)
# Out:
# (12221, 5408)

# %%
CV = 4

# initialize df for results
results = pd.DataFrame(
    index=np.arange(1000), columns=[
    "remove_corr_n", "scaler", "fs_model", "fs_m", "fs_univ_k", "pca_n", "tot_n_features", 
    "train_mcc", "val_mcc", "train_balanced_acc", "val_balanced_acc"]
)

i = 0  # counter

# remove strongly correlated features
for n_remove in [0, 10, 100, 250, 500, 750]:
    
    if n_remove:
        rm = RemoveCorrelatedFeatures(n_remove=n_remove)
        X_t = rm.fit_transform(X_train)
    else:
        X_t = X_train

    for scaler in ["no_scaling"]:

        if scaler != "no_scaling":
            X_t = scaler.fit_transform(X_t)
            scaler_name = scaler.__class__.__name__
        else:
            scaler_name = scaler

        # dimension reduction
        X_train_pca = PCA(n_components=25).fit_transform(X_t)

        # univariate selection
        selector_F = SelectKBest(f_classif, k="all").fit(X_t, Y_train)

        # model-based selection
        for model_name, model in [
            ("LinearSVC", LinearSVC(max_iter=15000, random_state=seed, class_weight="balanced"))
        ]:

            # fit the model
            model.fit(X_t, Y_train)

            # select m best features according to model
            for m in [10, 250, 500, 1000, 4000]:

                sel = SelectFromModel(model, prefit=True, threshold=-np.inf, max_features=m)
                model_sel = set(sel.get_support(indices=True))

                # select a total of k original features based on F-stat and MIC
                for k in [10, 20, 50, 75]:

                    # get best-scoring feature indices
                    F_sel = set(selector_F.scores_.argsort()[-k // 2:][::-1])
                    
                    # take union of all selected features
                    feature_sel = F_sel | model_sel

                    # add PCs
                    for n in [0, 10, 25]:

                        if n:
                            X_train_pca_sel = X_train_pca[:, :n]

                            # join with union of selected features
                            X_train_selection = np.concatenate(
                                (X_train_pca_sel, np.array(X_t)[:, list(feature_sel)]),
                                axis=1
                            )

                        else:
                            X_train_selection = np.array(X_t)[:, list(feature_sel)]

                        # Logistic Regression model 4-fold cv
                        out = [n_remove, scaler_name, model_name, m, k, n, X_train_selection.shape[-1]]

                        print("=" * 80)
                        print(" | ".join(str(o).ljust(10) for o in out), f" |  (i={i})")
                        print("=" * 80)

                        out.extend(
                            cv(model=LogisticRegression(max_iter=5000, penalty="none", class_weight="balanced", random_state=seed),
                               x=X_train_selection,
                               y=Y_train,
                               cv=CV,
                               n_jobs=-1
                              )
                        )

                        # store results
                        for col, value in zip(results.columns, out):
                            results[col][i] = value

                        i += 1
                    

        # baseline: only scaling and removal of correlated features 
        out = [n_remove, scaler_name, "na", "na", "na", 0, X_t.shape[-1]]

        print("=" * 80)
        print(" | ".join(str(o).ljust(10) for o in out), f" |  (i={i})")
        print("=" * 80)

        out.extend(
            cv(model=LogisticRegression(max_iter=5000, penalty="none", class_weight="balanced", random_state=seed),
               x=X_t,
               y=Y_train,
               cv=CV,
               n_jobs=-1
              )
        )

        # store results
        for col, value in zip(results.columns, out):
            results[col][i] = value

        i += 1
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 10         | 0          | 15          |  (i=0)
# ================================================================================
# test_balanced_acc              0.86 (± 0.00)       [0.86, 0.86, 0.87, 0.87]
# test_mcc                       0.20 (± 0.00)       [0.2, 0.2, 0.21, 0.21]
# --------------------------------------------------------------------------------
# Training MCC:                  0.21 (± 0.01)       [0.21, 0.21, 0.23, 0.22]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 10         | 10         | 25          |  (i=1)
# ================================================================================
# test_balanced_acc              0.87 (± 0.03)       [0.87, 0.89, 0.9, 0.82]
# test_mcc                       0.22 (± 0.02)       [0.21, 0.22, 0.24, 0.19]
# --------------------------------------------------------------------------------
# Training MCC:                  0.23 (± 0.01)       [0.21, 0.23, 0.24, 0.24]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 10         | 25         | 40          |  (i=2)
# ================================================================================
# test_balanced_acc              0.88 (± 0.03)       [0.91, 0.87, 0.92, 0.83]
# test_mcc                       0.25 (± 0.02)       [0.28, 0.25, 0.27, 0.22]
# --------------------------------------------------------------------------------
# Training MCC:                  0.28 (± 0.01)       [0.27, 0.27, 0.28, 0.29]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 20         | 0          | 20          |  (i=3)
# ================================================================================
# test_balanced_acc              0.87 (± 0.01)       [0.86, 0.88, 0.87, 0.85]
# test_mcc                       0.21 (± 0.01)       [0.2, 0.21, 0.21, 0.2]
# --------------------------------------------------------------------------------
# Training MCC:                  0.22 (± 0.01)       [0.2, 0.21, 0.23, 0.23]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 20         | 10         | 30          |  (i=4)
# ================================================================================
# test_balanced_acc              0.86 (± 0.05)       [0.87, 0.89, 0.91, 0.79]
# test_mcc                       0.22 (± 0.03)       [0.21, 0.22, 0.25, 0.17]
# --------------------------------------------------------------------------------
# Training MCC:                  0.23 (± 0.01)       [0.21, 0.23, 0.24, 0.25]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 20         | 25         | 45          |  (i=5)
# ================================================================================
# test_balanced_acc              0.88 (± 0.04)       [0.91, 0.86, 0.92, 0.82]
# test_mcc                       0.25 (± 0.03)       [0.28, 0.24, 0.27, 0.21]
# --------------------------------------------------------------------------------
# Training MCC:                  0.28 (± 0.01)       [0.27, 0.28, 0.28, 0.3]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 50         | 0          | 35          |  (i=6)
# ================================================================================
# test_balanced_acc              0.85 (± 0.02)       [0.86, 0.88, 0.85, 0.83]
# test_mcc                       0.22 (± 0.01)       [0.21, 0.23, 0.22, 0.2]
# --------------------------------------------------------------------------------
# Training MCC:                  0.25 (± 0.01)       [0.23, 0.24, 0.26, 0.26]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 50         | 10         | 45          |  (i=7)
# ================================================================================
# test_balanced_acc              0.86 (± 0.03)       [0.85, 0.88, 0.9, 0.82]
# test_mcc                       0.23 (± 0.02)       [0.22, 0.24, 0.26, 0.2]
# --------------------------------------------------------------------------------
# Training MCC:                  0.25 (± 0.01)       [0.23, 0.25, 0.27, 0.26]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 50         | 25         | 60          |  (i=8)
# ================================================================================
# test_balanced_acc              0.88 (± 0.04)       [0.9, 0.86, 0.92, 0.83]
# test_mcc                       0.26 (± 0.02)       [0.28, 0.25, 0.29, 0.23]
# --------------------------------------------------------------------------------
# Training MCC:                  0.30 (± 0.01)       [0.29, 0.3, 0.29, 0.32]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 75         | 0          | 48          |  (i=9)
# ================================================================================
# test_balanced_acc              0.88 (± 0.03)       [0.89, 0.91, 0.85, 0.86]
# test_mcc                       0.26 (± 0.02)       [0.26, 0.29, 0.25, 0.24]
# --------------------------------------------------------------------------------
# Training MCC:                  0.28 (± 0.02)       [0.26, 0.27, 0.32, 0.28]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 75         | 10         | 58          |  (i=10)
# ================================================================================
# test_balanced_acc              0.87 (± 0.03)       [0.91, 0.88, 0.88, 0.83]
# test_mcc                       0.27 (± 0.02)       [0.28, 0.27, 0.27, 0.24]
# --------------------------------------------------------------------------------
# Training MCC:                  0.30 (± 0.01)       [0.28, 0.29, 0.3, 0.3]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 10         | 75         | 25         | 73          |  (i=11)
# ================================================================================
# test_balanced_acc              0.90 (± 0.04)       [0.95, 0.88, 0.93, 0.85]
# test_mcc                       0.30 (± 0.02)       [0.32, 0.29, 0.31, 0.27]
# --------------------------------------------------------------------------------
# Training MCC:                  0.33 (± 0.02)       [0.31, 0.32, 0.32, 0.35]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 10         | 0          | 252         |  (i=12)
# ================================================================================
# test_balanced_acc              0.79 (± 0.04)       [0.77, 0.83, 0.81, 0.73]
# test_mcc                       0.48 (± 0.07)       [0.45, 0.58, 0.52, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 10         | 10         | 262         |  (i=13)
# ================================================================================
# test_balanced_acc              0.81 (± 0.04)       [0.8, 0.88, 0.76, 0.78]
# test_mcc                       0.49 (± 0.04)       [0.48, 0.57, 0.47, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 10         | 25         | 277         |  (i=14)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.74, 0.83, 0.78, 0.73]
# test_mcc                       0.49 (± 0.06)       [0.44, 0.59, 0.48, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 20         | 0          | 257         |  (i=15)
# ================================================================================
# test_balanced_acc              0.79 (± 0.04)       [0.79, 0.83, 0.81, 0.73]
# test_mcc                       0.51 (± 0.06)       [0.49, 0.59, 0.52, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 20         | 10         | 267         |  (i=16)
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.8, 0.81, 0.83, 0.78]
# test_mcc                       0.49 (± 0.03)       [0.47, 0.51, 0.53, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 20         | 25         | 282         |  (i=17)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.79, 0.81, 0.76, 0.71]
# test_mcc                       0.48 (± 0.04)       [0.49, 0.54, 0.44, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 50         | 0          | 271         |  (i=18)
# ================================================================================
# test_balanced_acc              0.79 (± 0.03)       [0.79, 0.85, 0.78, 0.76]
# test_mcc                       0.50 (± 0.05)       [0.49, 0.58, 0.47, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 50         | 10         | 281         |  (i=19)
# ================================================================================
# test_balanced_acc              0.79 (± 0.02)       [0.77, 0.81, 0.81, 0.78]
# test_mcc                       0.48 (± 0.03)       [0.47, 0.5, 0.52, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 50         | 25         | 296         |  (i=20)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.77, 0.83, 0.76, 0.73]
# test_mcc                       0.48 (± 0.06)       [0.46, 0.57, 0.45, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 75         | 0          | 283         |  (i=21)
# ================================================================================
# test_balanced_acc              0.78 (± 0.04)       [0.75, 0.85, 0.78, 0.73]
# test_mcc                       0.46 (± 0.07)       [0.41, 0.57, 0.49, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 75         | 10         | 293         |  (i=22)
# ================================================================================
# test_balanced_acc              0.78 (± 0.03)       [0.77, 0.83, 0.78, 0.76]
# test_mcc                       0.47 (± 0.05)       [0.45, 0.55, 0.47, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 250        | 75         | 25         | 308         |  (i=23)
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.8, 0.76, 0.75]
# test_mcc                       0.48 (± 0.04)       [0.44, 0.54, 0.46, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 10         | 0          | 501         |  (i=24)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.75, 0.83, 0.76, 0.73]
# test_mcc                       0.52 (± 0.07)       [0.48, 0.63, 0.53, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 10         | 10         | 511         |  (i=25)
# ================================================================================
# test_balanced_acc              0.80 (± 0.04)       [0.84, 0.78, 0.83, 0.75]
# test_mcc                       0.58 (± 0.06)       [0.61, 0.59, 0.63, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 10         | 25         | 526         |  (i=26)
# ================================================================================
# test_balanced_acc              0.77 (± 0.03)       [0.72, 0.81, 0.78, 0.75]
# test_mcc                       0.51 (± 0.07)       [0.45, 0.62, 0.51, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 20         | 0          | 506         |  (i=27)
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.8, 0.76, 0.73]
# test_mcc                       0.52 (± 0.04)       [0.5, 0.58, 0.52, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 20         | 10         | 516         |  (i=28)
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.75, 0.81, 0.78, 0.76]
# test_mcc                       0.54 (± 0.05)       [0.47, 0.6, 0.56, 0.51]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 20         | 25         | 531         |  (i=29)
# ================================================================================
# test_balanced_acc              0.75 (± 0.01)       [0.74, 0.76, 0.75, 0.73]
# test_mcc                       0.49 (± 0.02)       [0.46, 0.5, 0.47, 0.52]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 50         | 0          | 519         |  (i=30)
# ================================================================================
# test_balanced_acc              0.75 (± 0.01)       [0.74, 0.77, 0.75, 0.73]
# test_mcc                       0.49 (± 0.05)       [0.44, 0.57, 0.51, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 50         | 10         | 529         |  (i=31)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.76, 0.83, 0.73, 0.78]
# test_mcc                       0.53 (± 0.06)       [0.49, 0.62, 0.47, 0.55]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 50         | 25         | 544         |  (i=32)
# ================================================================================
# test_balanced_acc              0.77 (± 0.01)       [0.77, 0.76, 0.78, 0.78]
# test_mcc                       0.55 (± 0.01)       [0.53, 0.56, 0.56, 0.54]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 75         | 0          | 529         |  (i=33)
# ================================================================================
# test_balanced_acc              0.77 (± 0.04)       [0.77, 0.83, 0.75, 0.71]
# test_mcc                       0.52 (± 0.05)       [0.49, 0.6, 0.54, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 75         | 10         | 539         |  (i=34)
# ================================================================================
# test_balanced_acc              0.79 (± 0.04)       [0.79, 0.83, 0.83, 0.73]
# test_mcc                       0.55 (± 0.06)       [0.51, 0.61, 0.62, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 500        | 75         | 25         | 554         |  (i=35)
# ================================================================================
# test_balanced_acc              0.77 (± 0.03)       [0.74, 0.82, 0.8, 0.75]
# test_mcc                       0.54 (± 0.07)       [0.48, 0.64, 0.56, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 10         | 0          | 1001        |  (i=36)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.74, 0.8, 0.73, 0.73]
# test_mcc                       0.51 (± 0.05)       [0.47, 0.6, 0.46, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 10         | 10         | 1011        |  (i=37)
# ================================================================================
# test_balanced_acc              0.74 (± 0.03)       [0.71, 0.78, 0.76, 0.71]
# test_mcc                       0.45 (± 0.07)       [0.41, 0.56, 0.46, 0.37]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 10         | 25         | 1026        |  (i=38)
# ================================================================================
# test_balanced_acc              0.73 (± 0.01)       [0.72, 0.75, 0.71, 0.73]
# test_mcc                       0.47 (± 0.03)       [0.43, 0.5, 0.46, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 20         | 0          | 1003        |  (i=39)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.71, 0.8, 0.75, 0.73]
# test_mcc                       0.48 (± 0.07)       [0.41, 0.59, 0.49, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 20         | 10         | 1013        |  (i=40)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.72, 0.8, 0.71, 0.71]
# test_mcc                       0.48 (± 0.08)       [0.43, 0.61, 0.39, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 20         | 25         | 1028        |  (i=41)
# ================================================================================
# test_balanced_acc              0.72 (± 0.01)       [0.72, 0.73, 0.73, 0.71]
# test_mcc                       0.46 (± 0.04)       [0.42, 0.53, 0.45, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 50         | 0          | 1014        |  (i=42)
# ================================================================================
# test_balanced_acc              0.73 (± 0.04)       [0.72, 0.8, 0.68, 0.71]
# test_mcc                       0.45 (± 0.07)       [0.44, 0.55, 0.36, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 50         | 10         | 1024        |  (i=43)
# ================================================================================
# test_balanced_acc              0.75 (± 0.04)       [0.71, 0.81, 0.75, 0.71]
# test_mcc                       0.50 (± 0.08)       [0.41, 0.62, 0.51, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 50         | 25         | 1039        |  (i=44)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.77, 0.8, 0.71, 0.73]
# test_mcc                       0.49 (± 0.04)       [0.48, 0.54, 0.44, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 75         | 0          | 1022        |  (i=45)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.69, 0.76, 0.71, 0.71]
# test_mcc                       0.44 (± 0.06)       [0.39, 0.54, 0.4, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 75         | 10         | 1032        |  (i=46)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.71, 0.76, 0.73, 0.71]
# test_mcc                       0.46 (± 0.05)       [0.41, 0.55, 0.44, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 1000       | 75         | 25         | 1047        |  (i=47)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.74, 0.81, 0.71, 0.7]
# test_mcc                       0.47 (± 0.08)       [0.44, 0.6, 0.44, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 10         | 0          | 4000        |  (i=48)
# ================================================================================
# test_balanced_acc              0.72 (± 0.02)       [0.72, 0.75, 0.73, 0.7]
# test_mcc                       0.43 (± 0.03)       [0.41, 0.47, 0.44, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 10         | 10         | 4010        |  (i=49)
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.75, 0.8, 0.75, 0.73]
# test_mcc                       0.46 (± 0.05)       [0.45, 0.55, 0.43, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 10         | 25         | 4025        |  (i=50)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.71, 0.76, 0.71, 0.75]
# test_mcc                       0.42 (± 0.04)       [0.38, 0.49, 0.38, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 20         | 0          | 4000        |  (i=51)
# ================================================================================
# test_balanced_acc              0.72 (± 0.02)       [0.72, 0.75, 0.73, 0.7]
# test_mcc                       0.43 (± 0.03)       [0.41, 0.47, 0.44, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 20         | 10         | 4010        |  (i=52)
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.75, 0.8, 0.75, 0.73]
# test_mcc                       0.46 (± 0.05)       [0.45, 0.55, 0.43, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 20         | 25         | 4025        |  (i=53)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.71, 0.76, 0.71, 0.75]
# test_mcc                       0.42 (± 0.04)       [0.38, 0.49, 0.38, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 50         | 0          | 4001        |  (i=54)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.71, 0.76, 0.73, 0.71]
# test_mcc                       0.45 (± 0.06)       [0.41, 0.56, 0.45, 0.4]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 50         | 10         | 4011        |  (i=55)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.71, 0.78, 0.71, 0.7]
# test_mcc                       0.42 (± 0.06)       [0.41, 0.52, 0.38, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 50         | 25         | 4026        |  (i=56)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.75, 0.75, 0.7, 0.73]
# test_mcc                       0.43 (± 0.04)       [0.42, 0.49, 0.37, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 75         | 0          | 4003        |  (i=57)
# ================================================================================
# test_balanced_acc              0.71 (± 0.03)       [0.67, 0.76, 0.71, 0.7]
# test_mcc                       0.42 (± 0.06)       [0.35, 0.52, 0.39, 0.4]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 75         | 10         | 4013        |  (i=58)
# ================================================================================
# test_balanced_acc              0.72 (± 0.04)       [0.71, 0.76, 0.66, 0.73]
# test_mcc                       0.41 (± 0.06)       [0.4, 0.5, 0.33, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | LinearSVC  | 4000       | 75         | 25         | 4028        |  (i=59)
# ================================================================================
# test_balanced_acc              0.71 (± 0.01)       [0.71, 0.73, 0.71, 0.7]
# test_mcc                       0.41 (± 0.04)       [0.37, 0.49, 0.4, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 0          | no_scaling | na         | na         | na         | 0          | 5408        |  (i=60)
# ================================================================================
# test_balanced_acc              0.70 (± 0.01)       [0.69, 0.71, 0.7, 0.7]
# test_mcc                       0.40 (± 0.03)       [0.37, 0.44, 0.39, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 10         | 0          | 15          |  (i=61)
# ================================================================================
# test_balanced_acc              0.86 (± 0.01)       [0.86, 0.87, 0.87, 0.85]
# test_mcc                       0.21 (± 0.00)       [0.21, 0.21, 0.21, 0.2]
# --------------------------------------------------------------------------------
# Training MCC:                  0.21 (± 0.01)       [0.2, 0.21, 0.23, 0.22]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 10         | 10         | 25          |  (i=62)
# ================================================================================
# test_balanced_acc              0.87 (± 0.03)       [0.87, 0.89, 0.9, 0.81]
# test_mcc                       0.22 (± 0.02)       [0.21, 0.23, 0.25, 0.19]
# --------------------------------------------------------------------------------
# Training MCC:                  0.23 (± 0.01)       [0.21, 0.23, 0.24, 0.25]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 10         | 25         | 40          |  (i=63)
# ================================================================================
# test_balanced_acc              0.88 (± 0.03)       [0.91, 0.87, 0.92, 0.84]
# test_mcc                       0.26 (± 0.02)       [0.28, 0.25, 0.27, 0.22]
# --------------------------------------------------------------------------------
# Training MCC:                  0.28 (± 0.01)       [0.27, 0.28, 0.28, 0.3]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 20         | 0          | 20          |  (i=64)
# ================================================================================
# test_balanced_acc              0.86 (± 0.01)       [0.87, 0.87, 0.87, 0.84]
# test_mcc                       0.21 (± 0.01)       [0.21, 0.21, 0.21, 0.19]
# --------------------------------------------------------------------------------
# Training MCC:                  0.22 (± 0.01)       [0.2, 0.21, 0.24, 0.23]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 20         | 10         | 30          |  (i=65)
# ================================================================================
# test_balanced_acc              0.87 (± 0.05)       [0.87, 0.89, 0.91, 0.79]
# test_mcc                       0.22 (± 0.03)       [0.21, 0.23, 0.26, 0.18]
# --------------------------------------------------------------------------------
# Training MCC:                  0.24 (± 0.02)       [0.22, 0.23, 0.25, 0.26]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 20         | 25         | 45          |  (i=66)
# ================================================================================
# test_balanced_acc              0.87 (± 0.05)       [0.91, 0.86, 0.92, 0.8]
# test_mcc                       0.25 (± 0.03)       [0.28, 0.24, 0.28, 0.2]
# --------------------------------------------------------------------------------
# Training MCC:                  0.29 (± 0.01)       [0.27, 0.28, 0.28, 0.31]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 50         | 0          | 35          |  (i=67)
# ================================================================================
# test_balanced_acc              0.85 (± 0.02)       [0.86, 0.88, 0.85, 0.83]
# test_mcc                       0.22 (± 0.01)       [0.22, 0.23, 0.23, 0.21]
# --------------------------------------------------------------------------------
# Training MCC:                  0.25 (± 0.01)       [0.23, 0.24, 0.27, 0.26]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 50         | 10         | 45          |  (i=68)
# ================================================================================
# test_balanced_acc              0.86 (± 0.04)       [0.85, 0.88, 0.9, 0.8]
# test_mcc                       0.23 (± 0.02)       [0.22, 0.24, 0.26, 0.19]
# --------------------------------------------------------------------------------
# Training MCC:                  0.25 (± 0.01)       [0.23, 0.25, 0.27, 0.27]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 50         | 25         | 60          |  (i=69)
# ================================================================================
# test_balanced_acc              0.88 (± 0.04)       [0.9, 0.86, 0.93, 0.83]
# test_mcc                       0.27 (± 0.02)       [0.28, 0.26, 0.29, 0.24]
# --------------------------------------------------------------------------------
# Training MCC:                  0.30 (± 0.01)       [0.29, 0.3, 0.29, 0.33]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 75         | 0          | 48          |  (i=70)
# ================================================================================
# test_balanced_acc              0.88 (± 0.03)       [0.91, 0.91, 0.86, 0.84]
# test_mcc                       0.26 (± 0.02)       [0.27, 0.28, 0.26, 0.23]
# --------------------------------------------------------------------------------
# Training MCC:                  0.28 (± 0.02)       [0.27, 0.27, 0.31, 0.28]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 75         | 10         | 58          |  (i=71)
# ================================================================================
# test_balanced_acc              0.88 (± 0.03)       [0.91, 0.88, 0.89, 0.83]
# test_mcc                       0.27 (± 0.02)       [0.29, 0.27, 0.28, 0.24]
# --------------------------------------------------------------------------------
# Training MCC:                  0.30 (± 0.01)       [0.28, 0.29, 0.3, 0.31]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 10         | 75         | 25         | 73          |  (i=72)
# ================================================================================
# test_balanced_acc              0.90 (± 0.04)       [0.95, 0.88, 0.93, 0.85]
# test_mcc                       0.30 (± 0.02)       [0.32, 0.29, 0.31, 0.26]
# --------------------------------------------------------------------------------
# Training MCC:                  0.32 (± 0.02)       [0.31, 0.32, 0.32, 0.36]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 10         | 0          | 252         |  (i=73)
# ================================================================================
# test_balanced_acc              0.79 (± 0.05)       [0.8, 0.85, 0.78, 0.71]
# test_mcc                       0.48 (± 0.07)       [0.51, 0.57, 0.48, 0.37]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 10         | 10         | 262         |  (i=74)
# ================================================================================
# test_balanced_acc              0.79 (± 0.03)       [0.8, 0.83, 0.76, 0.76]
# test_mcc                       0.48 (± 0.04)       [0.49, 0.53, 0.49, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 10         | 25         | 277         |  (i=75)
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.8, 0.76, 0.73]
# test_mcc                       0.48 (± 0.02)       [0.49, 0.51, 0.47, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 20         | 0          | 257         |  (i=76)
# ================================================================================
# test_balanced_acc              0.78 (± 0.04)       [0.77, 0.85, 0.78, 0.73]
# test_mcc                       0.48 (± 0.07)       [0.46, 0.57, 0.48, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 20         | 10         | 267         |  (i=77)
# ================================================================================
# test_balanced_acc              0.78 (± 0.03)       [0.79, 0.83, 0.78, 0.75]
# test_mcc                       0.47 (± 0.04)       [0.48, 0.53, 0.48, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 20         | 25         | 282         |  (i=78)
# ================================================================================
# test_balanced_acc              0.77 (± 0.03)       [0.75, 0.81, 0.78, 0.73]
# test_mcc                       0.47 (± 0.04)       [0.44, 0.52, 0.48, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 50         | 0          | 271         |  (i=79)
# ================================================================================
# test_balanced_acc              0.79 (± 0.04)       [0.79, 0.86, 0.75, 0.76]
# test_mcc                       0.47 (± 0.06)       [0.49, 0.56, 0.42, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 50         | 10         | 281         |  (i=80)
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.8, 0.85, 0.81, 0.78]
# test_mcc                       0.53 (± 0.04)       [0.54, 0.57, 0.54, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 50         | 25         | 296         |  (i=81)
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.77, 0.8, 0.76, 0.71]
# test_mcc                       0.47 (± 0.04)       [0.45, 0.51, 0.5, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 75         | 0          | 283         |  (i=82)
# ================================================================================
# test_balanced_acc              0.79 (± 0.04)       [0.77, 0.86, 0.78, 0.75]
# test_mcc                       0.50 (± 0.06)       [0.48, 0.57, 0.53, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 10         | no_scaling | LinearSVC  | 250        | 75         | 10         | 293         |  (i=83)
# ================================================================================
# test_balanced_acc              0.78 (± 0.05)       [0.77, 0.86, 0.76, 0.74]
# test_mcc                       0.47 (± 0.07)       [0.44, 0.58, 0.46, 0.39]
# ...
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 500        | 75         | 0          | 531         |  (i=338)
# ================================================================================
# test_balanced_acc              0.75 (± 0.05)       [0.72, 0.8, 0.81, 0.68]
# test_mcc                       0.52 (± 0.08)       [0.49, 0.6, 0.61, 0.4]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 500        | 75         | 10         | 541         |  (i=339)
# ================================================================================
# test_balanced_acc              0.76 (± 0.01)       [0.76, 0.76, 0.76, 0.75]
# test_mcc                       0.50 (± 0.03)       [0.52, 0.54, 0.5, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 500        | 75         | 25         | 556         |  (i=340)
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.72, 0.8, 0.75, 0.78]
# test_mcc                       0.51 (± 0.06)       [0.43, 0.6, 0.48, 0.54]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 10         | 0          | 1000        |  (i=341)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.72, 0.8, 0.73, 0.75]
# test_mcc                       0.50 (± 0.06)       [0.46, 0.6, 0.45, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 10         | 10         | 1010        |  (i=342)
# ================================================================================
# test_balanced_acc              0.73 (± 0.02)       [0.72, 0.76, 0.73, 0.7]
# test_mcc                       0.46 (± 0.04)       [0.41, 0.51, 0.47, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 10         | 25         | 1025        |  (i=343)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.79, 0.78, 0.71, 0.7]
# test_mcc                       0.47 (± 0.06)       [0.49, 0.56, 0.43, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 20         | 0          | 1003        |  (i=344)
# ================================================================================
# test_balanced_acc              0.74 (± 0.03)       [0.76, 0.78, 0.7, 0.73]
# test_mcc                       0.48 (± 0.08)       [0.49, 0.59, 0.38, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 20         | 10         | 1013        |  (i=345)
# ================================================================================
# test_balanced_acc              0.74 (± 0.02)       [0.72, 0.76, 0.73, 0.73]
# test_mcc                       0.48 (± 0.05)       [0.41, 0.56, 0.47, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 20         | 25         | 1028        |  (i=346)
# ================================================================================
# test_balanced_acc              0.73 (± 0.04)       [0.74, 0.78, 0.71, 0.68]
# test_mcc                       0.46 (± 0.08)       [0.44, 0.59, 0.42, 0.4]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 50         | 0          | 1012        |  (i=347)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.74, 0.8, 0.73, 0.73]
# test_mcc                       0.51 (± 0.06)       [0.47, 0.61, 0.46, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 50         | 10         | 1022        |  (i=348)
# ================================================================================
# test_balanced_acc              0.74 (± 0.01)       [0.74, 0.76, 0.75, 0.73]
# test_mcc                       0.46 (± 0.04)       [0.45, 0.52, 0.48, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 50         | 25         | 1037        |  (i=349)
# ================================================================================
# test_balanced_acc              0.73 (± 0.03)       [0.76, 0.76, 0.7, 0.71]
# test_mcc                       0.48 (± 0.05)       [0.49, 0.55, 0.4, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 75         | 0          | 1020        |  (i=350)
# ================================================================================
# test_balanced_acc              0.76 (± 0.04)       [0.72, 0.81, 0.76, 0.73]
# test_mcc                       0.50 (± 0.06)       [0.45, 0.6, 0.5, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 75         | 10         | 1030        |  (i=351)
# ================================================================================
# test_balanced_acc              0.75 (± 0.04)       [0.72, 0.8, 0.78, 0.71]
# test_mcc                       0.48 (± 0.07)       [0.42, 0.57, 0.52, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 1000       | 75         | 25         | 1045        |  (i=352)
# ================================================================================
# test_balanced_acc              0.75 (± 0.03)       [0.75, 0.8, 0.75, 0.71]
# test_mcc                       0.50 (± 0.06)       [0.45, 0.6, 0.5, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 10         | 0          | 4000        |  (i=353)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.72, 0.81, 0.73, 0.7]
# test_mcc                       0.46 (± 0.09)       [0.42, 0.61, 0.43, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 10         | 10         | 4010        |  (i=354)
# ================================================================================
# test_balanced_acc              0.72 (± 0.04)       [0.72, 0.8, 0.7, 0.68]
# test_mcc                       0.44 (± 0.08)       [0.44, 0.57, 0.39, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 10         | 25         | 4025        |  (i=355)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.71, 0.76, 0.73, 0.7]
# test_mcc                       0.44 (± 0.04)       [0.39, 0.5, 0.43, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 20         | 0          | 4000        |  (i=356)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.72, 0.81, 0.73, 0.7]
# test_mcc                       0.46 (± 0.09)       [0.42, 0.61, 0.43, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 20         | 10         | 4010        |  (i=357)
# ================================================================================
# test_balanced_acc              0.72 (± 0.04)       [0.72, 0.8, 0.7, 0.68]
# test_mcc                       0.44 (± 0.08)       [0.44, 0.57, 0.39, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 20         | 25         | 4025        |  (i=358)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.71, 0.76, 0.73, 0.7]
# test_mcc                       0.44 (± 0.04)       [0.39, 0.5, 0.43, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 50         | 0          | 4000        |  (i=359)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.72, 0.81, 0.73, 0.7]
# test_mcc                       0.46 (± 0.09)       [0.42, 0.61, 0.43, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 50         | 10         | 4010        |  (i=360)
# ================================================================================
# test_balanced_acc              0.72 (± 0.04)       [0.72, 0.8, 0.7, 0.68]
# test_mcc                       0.44 (± 0.08)       [0.44, 0.57, 0.39, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 50         | 25         | 4025        |  (i=361)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.71, 0.76, 0.73, 0.7]
# test_mcc                       0.44 (± 0.04)       [0.39, 0.5, 0.43, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 75         | 0          | 4000        |  (i=362)
# ================================================================================
# test_balanced_acc              0.74 (± 0.04)       [0.72, 0.81, 0.73, 0.7]
# test_mcc                       0.46 (± 0.09)       [0.42, 0.61, 0.43, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 75         | 10         | 4010        |  (i=363)
# ================================================================================
# test_balanced_acc              0.72 (± 0.04)       [0.72, 0.8, 0.7, 0.68]
# test_mcc                       0.44 (± 0.08)       [0.44, 0.57, 0.39, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | LinearSVC  | 4000       | 75         | 25         | 4025        |  (i=364)
# ================================================================================
# test_balanced_acc              0.72 (± 0.03)       [0.71, 0.76, 0.73, 0.7]
# test_mcc                       0.44 (± 0.04)       [0.39, 0.5, 0.43, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]
#
# ================================================================================
# 750        | no_scaling | na         | na         | na         | 0          | 4658        |  (i=365)
# ================================================================================
# test_balanced_acc              0.72 (± 0.02)       [0.71, 0.75, 0.71, 0.73]
# test_mcc                       0.44 (± 0.06)       [0.37, 0.52, 0.42, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  1.00 (± 0.00)       [1.0, 1.0, 1.0, 1.0]

# %%
results = results.dropna(axis=0)
results.sort_values("val_mcc", ascending=False)
# Out:
#     remove_corr_n      scaler   fs_model fs_m fs_univ_k pca_n tot_n_features  \
# 25              0  no_scaling  LinearSVC  500        10    10            511
# 90             10  no_scaling  LinearSVC  500        20    25            531
# 34              0  no_scaling  LinearSVC  500        75    10            539
# 32              0  no_scaling  LinearSVC  500        50    25            544
# 153           100  no_scaling  LinearSVC  500        50    10            529
# ..            ...         ...        ...  ...       ...   ...            ...
# 0               0  no_scaling  LinearSVC   10        10     0             15
# 305           750  no_scaling  LinearSVC   10        10     0             15
# 244           500  no_scaling  LinearSVC   10        10     0             15
# 247           500  no_scaling  LinearSVC   10        20     0             20
# 309           750  no_scaling  LinearSVC   10        20    10             30
#
#     train_mcc   val_mcc train_balanced_acc val_balanced_acc
# 25          1  0.579906                  1          0.79903
# 90          1  0.565837                  1         0.783159
# 34          1  0.554758                  1         0.794895
# 32          1  0.549863                  1          0.77465
# 153         1  0.548383                  1         0.775054
# ..        ...       ...                ...              ...
# 0    0.214327  0.204679           0.882282         0.864615
# 305  0.215483  0.203306            0.88102         0.860934
# 244  0.215693  0.202758            0.88191          0.85781
# 247  0.219417   0.20208           0.886858          0.85749
# 309  0.230085  0.200983           0.888334         0.839722
#
# [366 rows x 11 columns]

# %%
results.to_csv(f"/kaggle/working/results_{scaler_name}.csv")
