# %%
seed = 123

# %%
from shutil import copyfile

copyfile(
    src = "/kaggle/input/bdc-p53/p53_helper_functions.py", 
    dst = "/kaggle/working/p53_helpers.py"
)

from p53_helpers import *

# load dataset (no NAs)
X, Y = load_p53_ds()
# sratified 80/20 split
X_train, X_test, Y_train, Y_test = split_p53(X, Y)
# Out:
# Using TensorFlow backend.
# Import completed after 4.5 sec
#
# CLASS RATIOS
# ================================================================================
# Training set active classes:   121/24927 (0.485 %)
# Test set active classes:       30/6232 (0.481 %)
#
# MATRIX DIMENSIONS
# ================================================================================
# TRAINING SET
# . Features:   (24927, 5408)
# . Classes:    (24927,)
# TEST SET
# . Features:   (6232, 5408)
# . Classes:    (6232,)

# %%
# make model and return the prop of the minority class to allow optimization the class weights
def make_model(
    x, y,
    u1=256,
    d1=0.5,
    lr=0.001,
    smart_init=True
):
    
    # define metrics
    metrics = [
        mcc,
        keras.metrics.TruePositives(name='tp'),
        keras.metrics.FalsePositives(name='fp'),
        keras.metrics.TrueNegatives(name='tn'),
        keras.metrics.FalseNegatives(name='fn'), 
        keras.metrics.BinaryAccuracy(name='accuracy'),
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall'),
        keras.metrics.AUC(name='auc', curve="PR")
    ]
    
    if smart_init:
        n_active = y.sum()
        n_inactive = len(y) - n_active
        b0 = tf.keras.initializers.Constant(np.log([n_active / n_inactive]))
    else:
        b0=None # random initialization

    # build & compile
    model = keras.Sequential([
        keras.layers.Dense(u1, activation='relu', input_shape=(x.shape[-1], )),
        keras.layers.Dropout(d1),
        keras.layers.Dense(1, activation='sigmoid', bias_initializer=b0)
    ])
    
    model.compile(
        optimizer=keras.optimizers.Adam(lr=lr),
        loss=keras.losses.BinaryCrossentropy(),
        metrics=metrics
    )
    
    return model

# %%
# to numpy arrays
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Preprocessing
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("clip", ClipFeatures(c=3))
])

X_train_prepped = pipe.fit_transform(X_train, Y_train)

# %%
# optimize class_weight hyperparameter after resampling

results = pd.DataFrame(
    index=np.arange(1000), columns=[
    "seed", "fold", "upsampler", "up_ratio", "cw_0",
    "precision", "recall", "auc", "mcc"]
)

i = 0
CV = 4

for seed in [1, 2, 3]:
    
    print("=" * 50)
    print("Random seed", seed)
    print("=" * 50)
    
    SKF = StratifiedKFold(n_splits=CV, shuffle=True, random_state=seed)
    folds = SKF.split(X_train_prepped, Y_train)

    for f, (train_idx, val_idx) in enumerate(folds):

        print('\nFold ', f)
        print("-" * 50)

        X_t, Y_t = X_train_prepped[train_idx], Y_train[train_idx]
        X_v, Y_v = X_train_prepped[val_idx], Y_train[val_idx]

        # optimize class weight 
        for cw_0 in [0.2, 0.3, 0.4, 0.5]:

            model = make_model(x=X_t, y=Y_t, lr=0.001)

            if cw_0:
                cw = {0: cw_0, 1: 1 - cw_0}
            else:
                cw = None # cw_0 = 0 no csl

            print(f"class_weight:       {str(cw)}")

            early_stopping = tf.keras.callbacks.EarlyStopping(
                monitor='val_mcc',
                verbose=1,
                patience=20,
                mode='max',
                restore_best_weights=True
            )

            out = model.fit(
                X_t,
                Y_t,
                batch_size=4096,
                epochs=75,
                callbacks=[early_stopping],
                validation_data=(X_v, Y_v),
                verbose=0,
                class_weight=cw
            )

            summary=[seed, f, "no_resampling", "no_resampling", cw_0]

            scores = [
                out.history["val_" + m][-1]
                for m in ["precision", "recall", "auc", "mcc"]
            ]
            
            print(f"Val fold MCC:       {scores[-1]:.2f}")
            
            summary.extend(scores)

            for col, value in zip(results.columns, summary):
                results[col][i] = value

            i += 1
# Out:
# ==================================================
# Random seed 1
# ==================================================
#
# Fold  0
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# Val fold MCC:       0.47
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# Val fold MCC:       0.53
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# Val fold MCC:       0.56
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# Val fold MCC:       0.53
#
# Fold  1
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# Val fold MCC:       0.52
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# Val fold MCC:       0.47
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# Val fold MCC:       0.48
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# Val fold MCC:       0.43
#
# Fold  2
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# Val fold MCC:       0.64
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# Val fold MCC:       0.66
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# Val fold MCC:       0.67
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# Val fold MCC:       0.61
#
# Fold  3
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# Val fold MCC:       0.45
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# Val fold MCC:       0.47
# class_weight:       {0: 0.4, 1: 0.6}
# Val fold MCC:       0.43
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# Val fold MCC:       0.42
# ==================================================
# Random seed 2
# ==================================================
#
# Fold  0
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00029: early stopping
# Val fold MCC:       0.48
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Val fold MCC:       0.56
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# Val fold MCC:       0.51
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# Val fold MCC:       0.51
#
# Fold  1
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Val fold MCC:       0.56
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00066: early stopping
# Val fold MCC:       0.58
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# Val fold MCC:       0.52
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# Val fold MCC:       0.54
#
# Fold  2
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# Val fold MCC:       0.59
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# Val fold MCC:       0.61
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# Val fold MCC:       0.57
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# Val fold MCC:       0.59
#
# Fold  3
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# Val fold MCC:       0.61
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# Val fold MCC:       0.61
# class_weight:       {0: 0.4, 1: 0.6}
# Val fold MCC:       0.50
# class_weight:       {0: 0.5, 1: 0.5}
# Val fold MCC:       0.56
# ==================================================
# Random seed 3
# ==================================================
#
# Fold  0
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# Val fold MCC:       0.53
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# Val fold MCC:       0.48
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# Val fold MCC:       0.44
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# Val fold MCC:       0.48
#
# Fold  1
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# Val fold MCC:       0.63
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Val fold MCC:       0.62
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# Val fold MCC:       0.59
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# Val fold MCC:       0.63
#
# Fold  2
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# Val fold MCC:       0.54
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# Val fold MCC:       0.50
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# Val fold MCC:       0.56
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# Val fold MCC:       0.49
#
# Fold  3
# --------------------------------------------------
# class_weight:       {0: 0.2, 1: 0.8}
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# Val fold MCC:       0.64
# class_weight:       {0: 0.3, 1: 0.7}
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Val fold MCC:       0.65
# class_weight:       {0: 0.4, 1: 0.6}
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# Val fold MCC:       0.64
# class_weight:       {0: 0.5, 1: 0.5}
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# Val fold MCC:       0.58

# %%
results = results.dropna(axis=0)

results.sort_values("mcc", ascending=False)
# Out:
#    seed fold      upsampler       up_ratio cw_0 precision    recall       auc  \
# 10    1    2  no_resampling  no_resampling  0.4  0.842105  0.516129  0.617497
# 9     1    2  no_resampling  no_resampling  0.3       0.8  0.516129  0.625074
# 45    3    3  no_resampling  no_resampling  0.3      0.68  0.566667  0.563631
# 44    3    3  no_resampling  no_resampling  0.2  0.642857       0.6  0.570328
# 8     1    2  no_resampling  no_resampling  0.2  0.761905  0.516129  0.618224
# 46    3    3  no_resampling  no_resampling  0.4  0.695652  0.533333  0.585067
# 36    3    1  no_resampling  no_resampling  0.2  0.714286       0.5  0.607992
# 39    3    1  no_resampling  no_resampling  0.5  0.777778  0.466667   0.57215
# 37    3    1  no_resampling  no_resampling  0.3  0.681818       0.5  0.607717
# 25    2    2  no_resampling  no_resampling  0.3  0.714286  0.483871  0.529204
# 11    1    2  no_resampling  no_resampling  0.5  0.923077  0.387097  0.603698
# 29    2    3  no_resampling  no_resampling  0.3  0.652174       0.5   0.63872
# 28    2    3  no_resampling  no_resampling  0.2  0.652174       0.5  0.649589
# 24    2    2  no_resampling  no_resampling  0.2  0.666667  0.516129  0.504984
# 38    3    1  no_resampling  no_resampling  0.4  0.722222  0.433333  0.607105
# 27    2    2  no_resampling  no_resampling  0.5       0.7  0.451613  0.571833
# 47    3    3  no_resampling  no_resampling  0.5  0.722222  0.433333  0.622693
# 21    2    1  no_resampling  no_resampling  0.3  0.652174       0.5  0.568791
# 26    2    2  no_resampling  no_resampling  0.4  0.722222  0.419355   0.51178
# 31    2    3  no_resampling  no_resampling  0.5  0.833333  0.333333  0.608698
# 17    2    0  no_resampling  no_resampling  0.3      0.75       0.4  0.443932
# 20    2    1  no_resampling  no_resampling  0.2       0.6       0.5  0.594987
# 2     1    0  no_resampling  no_resampling  0.4  0.636364  0.466667  0.575106
# 42    3    2  no_resampling  no_resampling  0.4      0.75  0.387097  0.483147
# 40    3    2  no_resampling  no_resampling  0.2  0.722222  0.419355  0.501411
# 23    2    1  no_resampling  no_resampling  0.5      0.65  0.433333  0.601832
# 32    3    0  no_resampling  no_resampling  0.2  0.576923       0.5  0.488959
# 1     1    0  no_resampling  no_resampling  0.3  0.583333  0.466667  0.576945
# 3     1    0  no_resampling  no_resampling  0.5  0.619048  0.433333  0.521953
# 4     1    1  no_resampling  no_resampling  0.2  0.518519  0.466667  0.404415
# 22    2    1  no_resampling  no_resampling  0.4  0.590909  0.433333  0.552836
# 18    2    0  no_resampling  no_resampling  0.4  0.714286  0.333333  0.455388
# 19    2    0  no_resampling  no_resampling  0.5  0.714286  0.333333  0.444424
# 30    2    3  no_resampling  no_resampling  0.4  0.631579       0.4  0.623523
# 41    3    2  no_resampling  no_resampling  0.3  0.631579  0.387097  0.503333
# 43    3    2  no_resampling  no_resampling  0.5  0.714286  0.322581  0.476437
# 35    3    0  no_resampling  no_resampling  0.5  0.565217  0.433333  0.487809
# 6     1    1  no_resampling  no_resampling  0.4  0.684211  0.433333  0.460062
# 33    3    0  no_resampling  no_resampling  0.3  0.571429       0.4  0.440549
# 16    2    0  no_resampling  no_resampling  0.2     0.625  0.333333  0.438764
# 13    1    3  no_resampling  no_resampling  0.3      0.52  0.433333   0.32215
# 0     1    0  no_resampling  no_resampling  0.2  0.481481  0.433333   0.49465
# 5     1    1  no_resampling  no_resampling  0.3  0.666667       0.4  0.411169
# 12    1    3  no_resampling  no_resampling  0.2  0.521739       0.4  0.343267
# 34    3    0  no_resampling  no_resampling  0.4  0.578947  0.366667  0.459123
# 7     1    1  no_resampling  no_resampling  0.5  0.578947  0.366667  0.388703
# 14    1    3  no_resampling  no_resampling  0.4  0.588235  0.333333  0.386654
# 15    1    3  no_resampling  no_resampling  0.5     0.625  0.333333  0.335044
#
#          mcc
# 10   0.67389
# 9   0.660289
# 45  0.652744
# 44  0.642139
# 8   0.640393
# 46  0.638138
# 36   0.63239
# 39  0.630167
# 37  0.623213
# 25  0.610179
# 11  0.607163
# 29  0.606341
# 28  0.606341
# 24  0.593611
# 38   0.58929
# 27  0.587417
# 47  0.579866
# 21  0.579188
# 26  0.573321
# 31  0.563677
# 17  0.561651
# 20  0.560984
# 2   0.555801
# 42  0.555235
# 40  0.543584
# 23  0.541312
# 32  0.534814
# 1   0.531378
# 3   0.530816
# 4   0.515696
# 22  0.515454
# 18  0.508987
# 19  0.505608
# 30  0.504446
# 41   0.50266
# 43  0.487892
# 35  0.483886
# 6   0.482588
# 33  0.480925
# 16  0.475457
# 13  0.471587
# 0   0.466711
# 5   0.465803
# 12  0.453511
# 34  0.437052
# 7   0.433193
# 14  0.431381
# 15  0.423439

# %%
results.to_csv(f"/kaggle/working/results_NN_CSL_no_resampling.csv")
