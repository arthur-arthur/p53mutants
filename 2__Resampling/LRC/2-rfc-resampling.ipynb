# %%
seed = 123

# %%
from shutil import copyfile

copyfile(
    src = "/kaggle/input/bdc-p53/p53_helper_functions.py", 
    dst = "/kaggle/working/p53_helpers.py"
)

from p53_helpers import *

# load dataset (no NAs)
X, Y = load_p53_ds()
# sratified 80/20 split
X_train, X_test, Y_train, Y_test = split_p53(X, Y)
# Out:
# Using TensorFlow backend.
# Import completed after 3.4 sec
#
# CLASS RATIOS
# ================================================================================
# Training set active classes:   121/24927 (0.485 %)
# Test set active classes:       30/6232 (0.481 %)
#
# MATRIX DIMENSIONS
# ================================================================================
# TRAINING SET
# . Features:   (24927, 5408)
# . Classes:    (24927,)
# TEST SET
# . Features:   (6232, 5408)
# . Classes:    (6232,)

# %%
# Dimensionality-reduction (optimized cf. 1__RFC__DimRed_A/B notebooks)
    # deze is MCC=0.5889 on downsampled DS
FU = FeatureUnion([
    ("fs_univ", SelectKBest(f_classif, k=20)),
    ("fs_model", SelectFromModel(
        ExtraTreesClassifier(n_estimators=100, random_state=seed), threshold=-np.inf, max_features=125
    ))
])

pipe = Pipeline([
    ("remove_corr", RemoveCorrelatedFeatures(n_remove=10)),
    ("scale", StandardScaler()),
    ("fs", FU)
])

# perform PP steps and fit as a baseline to evaluate resampling algorithms
X_train_prepped = pipe.fit_transform(X_train, Y_train)

# %%
CV = 4

results = pd.DataFrame(
    index=np.arange(1000), columns=[
    "seed", "upsampler", "downsampler", "up_class_ratio", "down_vs_up_ratio","final_class_ratio",
    "train_mcc", "val_mcc", "train_bal_acc", "val_bal_acc"]
)

i = 0

# the stochastic nature of the resampling algorithms resulted in large variability, therefore the different
# algorithms were repeated and the average validation fold performance (4-fold CV) was used to evaluate
# the downstream performance of the different resampling algorithms
for seed in [1]:
    
    # upsampling minority class
    for up in [RandomOverSampler, SMOTE, ADASYN, SVMSMOTE]:

        for down in [RandomUnderSampler]:

            for up_ratio in [0.01, 0.05, 0.1, 0.2]:
                
                for down_vs_up_ratio in [1, 1.25, 1.5, 1.75, 2]:

                    down_ratio = down_vs_up_ratio * up_ratio

                    pipe = Pipeline([
                        ("up", up(sampling_strategy=up_ratio, random_state=seed)),
                        ("down", down(sampling_strategy=down_ratio, random_state=seed)),
                        ("clf", RandomForestClassifier(random_state=seed, class_weight="balanced", min_samples_leaf=10, n_estimators=500, max_depth=15))
                    ])

                    out = [seed, up.__name__, down.__name__, up_ratio, down_vs_up_ratio, down_ratio]

                    print("=" * 80)
                    print(" | ".join(str(o) for o in out[1:]))
                    print("=" * 80)

                    # 4-fold CV w/ LR
                    scores = cv(
                        model=pipe, 
                        x=X_train_prepped, 
                        y=Y_train,
                        cv=CV,
                        n_jobs=-1
                    )
                    out.extend(scores)

                    # write to results df
                    for col, value in zip(results.columns, out):
                        results[col][i] = value

                    i += 1

    # add as a reference: no resampling
    out = [seed, "no_resampling", "no_resampling", "NA", "NA", "NA"]

    scores = cv(
        model=RandomForestClassifier(random_state=seed, class_weight="balanced", min_samples_leaf=10, n_estimators=500, max_depth=15),
        x=X_train_prepped,
        y=Y_train,
        cv=CV,
        n_jobs=-1
    )

    out.extend(scores)

    for col, value in zip(results.columns, out):
        results[col][i] = value

    i += 1
# Out:
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.01 | 1 | 0.01
# ================================================================================
# test_balanced_acc              0.75 (± 0.02)       [0.73, 0.76, 0.77, 0.75]
# test_mcc                       0.49 (± 0.05)       [0.57, 0.43, 0.49, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  0.80 (± 0.02)       [0.77, 0.82, 0.82, 0.79]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.01 | 1.25 | 0.0125
# ================================================================================
# test_balanced_acc              0.75 (± 0.02)       [0.73, 0.76, 0.77, 0.75]
# test_mcc                       0.47 (± 0.04)       [0.54, 0.42, 0.47, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.78 (± 0.02)       [0.76, 0.8, 0.82, 0.77]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.01 | 1.5 | 0.015
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.73, 0.76, 0.8, 0.75]
# test_mcc                       0.48 (± 0.05)       [0.56, 0.42, 0.5, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.02)       [0.74, 0.78, 0.8, 0.76]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.01 | 1.75 | 0.0175
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.78, 0.8, 0.75]
# test_mcc                       0.49 (± 0.06)       [0.58, 0.44, 0.51, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.76 (± 0.02)       [0.73, 0.78, 0.8, 0.76]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.01 | 2 | 0.02
# ================================================================================
# test_balanced_acc              0.78 (± 0.03)       [0.77, 0.78, 0.82, 0.75]
# test_mcc                       0.49 (± 0.06)       [0.57, 0.44, 0.5, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.02)       [0.72, 0.77, 0.77, 0.75]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.05 | 1 | 0.05
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.78, 0.79, 0.77]
# test_mcc                       0.49 (± 0.05)       [0.57, 0.44, 0.48, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  0.78 (± 0.01)       [0.76, 0.78, 0.79, 0.78]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.05 | 1.25 | 0.0625
# ================================================================================
# test_balanced_acc              0.77 (± 0.01)       [0.75, 0.76, 0.79, 0.76]
# test_mcc                       0.49 (± 0.06)       [0.6, 0.43, 0.47, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.01)       [0.75, 0.79, 0.78, 0.76]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.05 | 1.5 | 0.07500000000000001
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.75, 0.76, 0.8, 0.76]
# test_mcc                       0.48 (± 0.06)       [0.57, 0.41, 0.48, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.01)       [0.75, 0.76, 0.76, 0.74]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.05 | 1.75 | 0.08750000000000001
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.75, 0.78, 0.8, 0.76]
# test_mcc                       0.49 (± 0.05)       [0.58, 0.45, 0.48, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.74 (± 0.01)       [0.73, 0.76, 0.75, 0.74]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.05 | 2 | 0.1
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.8, 0.8, 0.76]
# test_mcc                       0.48 (± 0.05)       [0.57, 0.44, 0.47, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.72 (± 0.01)       [0.72, 0.72, 0.73, 0.72]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.1 | 1 | 0.1
# ================================================================================
# test_balanced_acc              0.76 (± 0.02)       [0.73, 0.76, 0.79, 0.77]
# test_mcc                       0.47 (± 0.06)       [0.57, 0.41, 0.44, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.02)       [0.77, 0.74, 0.78, 0.78]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.1 | 1.25 | 0.125
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.78, 0.79, 0.76]
# test_mcc                       0.48 (± 0.05)       [0.57, 0.44, 0.44, 0.48]
# --------------------------------------------------------------------------------
# Training MCC:                  0.76 (± 0.01)       [0.76, 0.77, 0.74, 0.77]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.1 | 1.5 | 0.15000000000000002
# ================================================================================
# test_balanced_acc              0.78 (± 0.01)       [0.77, 0.8, 0.79, 0.76]
# test_mcc                       0.50 (± 0.07)       [0.62, 0.46, 0.46, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.01)       [0.75, 0.76, 0.76, 0.74]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.1 | 1.75 | 0.17500000000000002
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.8, 0.79, 0.76]
# test_mcc                       0.49 (± 0.04)       [0.56, 0.47, 0.46, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.01)       [0.75, 0.75, 0.76, 0.74]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.1 | 2 | 0.2
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.8, 0.8, 0.76]
# test_mcc                       0.49 (± 0.05)       [0.58, 0.45, 0.47, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.74 (± 0.01)       [0.73, 0.74, 0.75, 0.73]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.2 | 1 | 0.2
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.78, 0.79, 0.77]
# test_mcc                       0.49 (± 0.05)       [0.57, 0.43, 0.47, 0.49]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.02)       [0.78, 0.74, 0.79, 0.78]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.2 | 1.25 | 0.25
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.8, 0.79, 0.76]
# test_mcc                       0.49 (± 0.05)       [0.57, 0.46, 0.46, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.76 (± 0.01)       [0.76, 0.76, 0.75, 0.77]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.2 | 1.5 | 0.30000000000000004
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.73, 0.8, 0.79, 0.76]
# test_mcc                       0.49 (± 0.04)       [0.57, 0.46, 0.47, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.01)       [0.75, 0.75, 0.76, 0.76]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.2 | 1.75 | 0.35000000000000003
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.75, 0.8, 0.8, 0.76]
# test_mcc                       0.48 (± 0.04)       [0.56, 0.44, 0.48, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.01)       [0.74, 0.74, 0.77, 0.75]
#
# ================================================================================
# RandomOverSampler | RandomUnderSampler | 0.2 | 2 | 0.4
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.8, 0.8, 0.76]
# test_mcc                       0.49 (± 0.06)       [0.58, 0.46, 0.47, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  0.74 (± 0.01)       [0.73, 0.76, 0.76, 0.73]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.01 | 1 | 0.01
# ================================================================================
# test_balanced_acc              0.76 (± 0.03)       [0.75, 0.76, 0.8, 0.73]
# test_mcc                       0.51 (± 0.08)       [0.63, 0.43, 0.54, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.80 (± 0.02)       [0.78, 0.82, 0.81, 0.8]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.01 | 1.25 | 0.0125
# ================================================================================
# test_balanced_acc              0.77 (± 0.03)       [0.77, 0.76, 0.82, 0.75]
# test_mcc                       0.51 (± 0.07)       [0.61, 0.43, 0.55, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  0.79 (± 0.02)       [0.76, 0.81, 0.8, 0.78]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.01 | 1.5 | 0.015
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.76, 0.8, 0.76]
# test_mcc                       0.50 (± 0.07)       [0.61, 0.43, 0.48, 0.47]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.02)       [0.75, 0.8, 0.79, 0.76]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.01 | 1.75 | 0.0175
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.78, 0.8, 0.76]
# test_mcc                       0.50 (± 0.06)       [0.61, 0.44, 0.49, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.02)       [0.74, 0.78, 0.8, 0.75]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.01 | 2 | 0.02
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.78, 0.8, 0.76]
# test_mcc                       0.49 (± 0.06)       [0.58, 0.44, 0.48, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.75 (± 0.02)       [0.73, 0.75, 0.77, 0.74]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.05 | 1 | 0.05
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.78, 0.8, 0.84, 0.8]
# test_mcc                       0.49 (± 0.06)       [0.58, 0.42, 0.5, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.70 (± 0.01)       [0.71, 0.71, 0.72, 0.68]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.05 | 1.25 | 0.0625
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.78, 0.78, 0.84, 0.8]
# test_mcc                       0.46 (± 0.06)       [0.56, 0.38, 0.46, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  0.68 (± 0.01)       [0.69, 0.68, 0.69, 0.66]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.05 | 1.5 | 0.07500000000000001
# ================================================================================
# test_balanced_acc              0.80 (± 0.03)       [0.78, 0.8, 0.85, 0.78]
# test_mcc                       0.45 (± 0.06)       [0.55, 0.4, 0.47, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  0.67 (± 0.02)       [0.68, 0.67, 0.69, 0.65]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.05 | 1.75 | 0.08750000000000001
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.78, 0.81, 0.83, 0.8]
# test_mcc                       0.45 (± 0.05)       [0.53, 0.41, 0.45, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  0.66 (± 0.02)       [0.67, 0.66, 0.68, 0.64]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.05 | 2 | 0.1
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.78, 0.81, 0.85, 0.81]
# test_mcc                       0.45 (± 0.05)       [0.54, 0.41, 0.44, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.02)       [0.66, 0.65, 0.67, 0.62]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.1 | 1 | 0.1
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.8, 0.85, 0.8]
# test_mcc                       0.47 (± 0.06)       [0.56, 0.41, 0.48, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  0.69 (± 0.02)       [0.69, 0.72, 0.68, 0.67]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.1 | 1.25 | 0.125
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.8, 0.87, 0.8]
# test_mcc                       0.45 (± 0.06)       [0.56, 0.41, 0.46, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  0.67 (± 0.01)       [0.68, 0.69, 0.67, 0.65]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.1 | 1.5 | 0.15000000000000002
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.85, 0.8]
# test_mcc                       0.44 (± 0.05)       [0.53, 0.43, 0.43, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  0.66 (± 0.01)       [0.66, 0.67, 0.66, 0.63]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.1 | 1.75 | 0.17500000000000002
# ================================================================================
# test_balanced_acc              0.82 (± 0.02)       [0.8, 0.83, 0.85, 0.8]
# test_mcc                       0.45 (± 0.06)       [0.54, 0.43, 0.44, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  0.64 (± 0.01)       [0.65, 0.66, 0.64, 0.62]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.1 | 2 | 0.2
# ================================================================================
# test_balanced_acc              0.82 (± 0.02)       [0.78, 0.83, 0.85, 0.81]
# test_mcc                       0.44 (± 0.04)       [0.51, 0.43, 0.42, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  0.64 (± 0.02)       [0.65, 0.65, 0.64, 0.61]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.2 | 1 | 0.2
# ================================================================================
# test_balanced_acc              0.80 (± 0.03)       [0.78, 0.78, 0.85, 0.8]
# test_mcc                       0.45 (± 0.07)       [0.56, 0.38, 0.45, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  0.67 (± 0.02)       [0.69, 0.69, 0.67, 0.65]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.2 | 1.25 | 0.25
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.85, 0.8]
# test_mcc                       0.44 (± 0.07)       [0.56, 0.41, 0.43, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  0.66 (± 0.02)       [0.69, 0.67, 0.65, 0.62]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.2 | 1.5 | 0.30000000000000004
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.85, 0.8]
# test_mcc                       0.44 (± 0.06)       [0.54, 0.41, 0.44, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.02)       [0.68, 0.65, 0.64, 0.63]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.2 | 1.75 | 0.35000000000000003
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.78, 0.81, 0.87, 0.81]
# test_mcc                       0.45 (± 0.06)       [0.55, 0.41, 0.45, 0.41]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.00)       [0.65, 0.64, 0.65, 0.64]
#
# ================================================================================
# SMOTE | RandomUnderSampler | 0.2 | 2 | 0.4
# ================================================================================
# test_balanced_acc              0.82 (± 0.02)       [0.8, 0.83, 0.85, 0.81]
# test_mcc                       0.45 (± 0.06)       [0.55, 0.42, 0.42, 0.39]
# --------------------------------------------------------------------------------
# Training MCC:                  0.63 (± 0.01)       [0.65, 0.64, 0.62, 0.62]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.01 | 1 | 0.01
# ================================================================================
# test_balanced_acc              nan (± nan)         [0.77, nan, nan, nan]
# test_mcc                       nan (± nan)         [0.62, nan, nan, nan]
# --------------------------------------------------------------------------------
# Training MCC:                  nan (± nan)         [0.76, nan, nan, nan]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.01 | 1.25 | 0.0125
# ================================================================================
# test_balanced_acc              0.77 (± 0.02)       [0.77, 0.76, 0.8, 0.75]
# test_mcc                       0.49 (± 0.08)       [0.62, 0.41, 0.48, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.76 (± 0.01)       [0.76, 0.77, 0.76, 0.76]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.01 | 1.5 | 0.015
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.76, 0.82, 0.76]
# test_mcc                       0.49 (± 0.07)       [0.61, 0.41, 0.49, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.74 (± 0.00)       [0.74, 0.75, 0.73, 0.73]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.01 | 1.75 | 0.0175
# ================================================================================
# test_balanced_acc              0.78 (± 0.03)       [0.77, 0.76, 0.84, 0.75]
# test_mcc                       0.48 (± 0.08)       [0.61, 0.41, 0.51, 0.4]
# --------------------------------------------------------------------------------
# Training MCC:                  0.73 (± 0.02)       [0.73, 0.76, 0.73, 0.7]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.01 | 2 | 0.02
# ================================================================================
# test_balanced_acc              0.78 (± 0.02)       [0.77, 0.76, 0.82, 0.76]
# test_mcc                       0.48 (± 0.07)       [0.59, 0.41, 0.47, 0.43]
# --------------------------------------------------------------------------------
# Training MCC:                  0.72 (± 0.01)       [0.71, 0.73, 0.72, 0.71]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.05 | 1 | 0.05
# ================================================================================
# test_balanced_acc              nan (± nan)         [0.77, 0.79, nan, 0.8]
# test_mcc                       nan (± nan)         [0.54, 0.35, nan, 0.38]
# --------------------------------------------------------------------------------
# Training MCC:                  nan (± nan)         [0.67, 0.6, nan, 0.62]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.05 | 1.25 | 0.0625
# ================================================================================
# test_balanced_acc              0.81 (± 0.04)       [0.77, 0.81, 0.87, 0.78]
# test_mcc                       0.41 (± 0.06)       [0.51, 0.38, 0.44, 0.34]
# --------------------------------------------------------------------------------
# Training MCC:                  0.62 (± 0.01)       [0.64, 0.61, 0.62, 0.61]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.05 | 1.5 | 0.07500000000000001
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.87, 0.79]
# test_mcc                       0.41 (± 0.06)       [0.49, 0.36, 0.44, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  0.61 (± 0.02)       [0.63, 0.59, 0.62, 0.6]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.05 | 1.75 | 0.08750000000000001
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.87, 0.79]
# test_mcc                       0.42 (± 0.07)       [0.52, 0.36, 0.43, 0.36]
# --------------------------------------------------------------------------------
# Training MCC:                  0.60 (± 0.03)       [0.64, 0.57, 0.62, 0.59]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.05 | 2 | 0.1
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.81, 0.87, 0.79]
# test_mcc                       0.40 (± 0.05)       [0.48, 0.36, 0.43, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  0.60 (± 0.03)       [0.64, 0.57, 0.61, 0.59]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.1 | 1 | 0.1
# ================================================================================
# test_balanced_acc              nan (± nan)         [0.8, nan, 0.87, 0.8]
# test_mcc                       nan (± nan)         [0.51, nan, 0.44, 0.36]
# --------------------------------------------------------------------------------
# Training MCC:                  nan (± nan)         [0.62, nan, 0.62, 0.59]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.1 | 1.25 | 0.125
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.81, 0.87, 0.79]
# test_mcc                       0.41 (± 0.07)       [0.51, 0.36, 0.44, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  0.60 (± 0.02)       [0.63, 0.58, 0.61, 0.58]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.1 | 1.5 | 0.15000000000000002
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.81, 0.87, 0.79]
# test_mcc                       0.41 (± 0.05)       [0.47, 0.35, 0.44, 0.36]
# --------------------------------------------------------------------------------
# Training MCC:                  0.59 (± 0.01)       [0.6, 0.57, 0.61, 0.58]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.1 | 1.75 | 0.17500000000000002
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.83, 0.87, 0.79]
# test_mcc                       0.41 (± 0.06)       [0.49, 0.36, 0.43, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  0.58 (± 0.02)       [0.62, 0.56, 0.59, 0.57]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.1 | 2 | 0.2
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.81, 0.87, 0.79]
# test_mcc                       0.40 (± 0.06)       [0.48, 0.34, 0.42, 0.34]
# --------------------------------------------------------------------------------
# Training MCC:                  0.58 (± 0.02)       [0.6, 0.55, 0.59, 0.57]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.2 | 1 | 0.2
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.79, 0.87, 0.79]
# test_mcc                       0.40 (± 0.07)       [0.48, 0.34, 0.44, 0.33]
# --------------------------------------------------------------------------------
# Training MCC:                  0.60 (± 0.03)       [0.64, 0.58, 0.62, 0.56]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.2 | 1.25 | 0.25
# ================================================================================
# test_balanced_acc              0.81 (± 0.03)       [0.78, 0.79, 0.87, 0.81]
# test_mcc                       0.40 (± 0.06)       [0.48, 0.34, 0.43, 0.34]
# --------------------------------------------------------------------------------
# Training MCC:                  0.58 (± 0.03)       [0.63, 0.58, 0.58, 0.54]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.2 | 1.5 | 0.30000000000000004
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.81, 0.87, 0.81]
# test_mcc                       0.40 (± 0.06)       [0.49, 0.35, 0.43, 0.35]
# --------------------------------------------------------------------------------
# Training MCC:                  0.58 (± 0.03)       [0.62, 0.58, 0.6, 0.54]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.2 | 1.75 | 0.35000000000000003
# ================================================================================
# test_balanced_acc              0.83 (± 0.03)       [0.8, 0.84, 0.87, 0.81]
# test_mcc                       0.40 (± 0.05)       [0.48, 0.38, 0.42, 0.34]
# --------------------------------------------------------------------------------
# Training MCC:                  0.58 (± 0.03)       [0.63, 0.56, 0.58, 0.54]
#
# ================================================================================
# ADASYN | RandomUnderSampler | 0.2 | 2 | 0.4
# ================================================================================
# test_balanced_acc              0.82 (± 0.03)       [0.8, 0.83, 0.87, 0.79]
# test_mcc                       0.40 (± 0.06)       [0.49, 0.36, 0.42, 0.32]
# --------------------------------------------------------------------------------
# Training MCC:                  0.57 (± 0.02)       [0.6, 0.55, 0.58, 0.54]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.01 | 1 | 0.01
# ================================================================================
# test_balanced_acc              0.78 (± 0.01)       [0.77, 0.78, 0.79, 0.77]
# test_mcc                       0.53 (± 0.06)       [0.62, 0.45, 0.51, 0.53]
# --------------------------------------------------------------------------------
# Training MCC:                  0.80 (± 0.02)       [0.76, 0.82, 0.82, 0.78]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.01 | 1.25 | 0.0125
# ================================================================================
# test_balanced_acc              0.78 (± 0.01)       [0.77, 0.78, 0.8, 0.78]
# test_mcc                       0.52 (± 0.05)       [0.59, 0.45, 0.53, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  0.78 (± 0.03)       [0.75, 0.81, 0.81, 0.75]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.01 | 1.5 | 0.015
# ================================================================================
# test_balanced_acc              0.79 (± 0.02)       [0.77, 0.78, 0.8, 0.8]
# test_mcc                       0.51 (± 0.04)       [0.56, 0.45, 0.51, 0.51]
# --------------------------------------------------------------------------------
# Training MCC:                  0.77 (± 0.03)       [0.75, 0.8, 0.79, 0.73]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.01 | 1.75 | 0.0175
# ================================================================================
# test_balanced_acc              0.79 (± 0.02)       [0.77, 0.78, 0.8, 0.8]
# test_mcc                       0.50 (± 0.03)       [0.53, 0.44, 0.51, 0.51]
# --------------------------------------------------------------------------------
# Training MCC:                  0.76 (± 0.03)       [0.73, 0.79, 0.79, 0.72]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.01 | 2 | 0.02
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.77, 0.8, 0.82, 0.8]
# test_mcc                       0.50 (± 0.03)       [0.52, 0.45, 0.53, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  0.74 (± 0.02)       [0.71, 0.75, 0.77, 0.73]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.05 | 1 | 0.05
# ================================================================================
# test_balanced_acc              0.80 (± 0.01)       [0.78, 0.81, 0.8, 0.78]
# test_mcc                       0.51 (± 0.05)       [0.58, 0.46, 0.53, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.70 (± 0.05)       [0.67, 0.73, 0.75, 0.64]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.05 | 1.25 | 0.0625
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.8, 0.81, 0.82, 0.78]
# test_mcc                       0.50 (± 0.05)       [0.58, 0.46, 0.51, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.67 (± 0.04)       [0.64, 0.7, 0.71, 0.63]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.05 | 1.5 | 0.07500000000000001
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.78, 0.81, 0.84, 0.8]
# test_mcc                       0.50 (± 0.04)       [0.55, 0.46, 0.53, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.04)       [0.62, 0.68, 0.7, 0.6]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.05 | 1.75 | 0.08750000000000001
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.8, 0.81, 0.84, 0.8]
# test_mcc                       0.49 (± 0.05)       [0.55, 0.45, 0.53, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.64 (± 0.05)       [0.61, 0.67, 0.7, 0.59]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.05 | 2 | 0.1
# ================================================================================
# test_balanced_acc              0.82 (± 0.02)       [0.8, 0.83, 0.84, 0.8]
# test_mcc                       0.48 (± 0.04)       [0.52, 0.45, 0.52, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  0.63 (± 0.04)       [0.6, 0.66, 0.68, 0.59]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.1 | 1 | 0.1
# ================================================================================
# test_balanced_acc              0.80 (± 0.01)       [0.78, 0.81, 0.8, 0.78]
# test_mcc                       0.51 (± 0.05)       [0.58, 0.47, 0.51, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.68 (± 0.03)       [0.65, 0.7, 0.72, 0.66]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.1 | 1.25 | 0.125
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.78, 0.8, 0.84, 0.78]
# test_mcc                       0.49 (± 0.06)       [0.57, 0.43, 0.53, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.66 (± 0.04)       [0.63, 0.68, 0.71, 0.63]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.1 | 1.5 | 0.15000000000000002
# ================================================================================
# test_balanced_acc              0.81 (± 0.01)       [0.8, 0.81, 0.82, 0.8]
# test_mcc                       0.49 (± 0.06)       [0.58, 0.43, 0.5, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.03)       [0.62, 0.67, 0.68, 0.62]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.1 | 1.75 | 0.17500000000000002
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.8, 0.81, 0.84, 0.8]
# test_mcc                       0.49 (± 0.05)       [0.56, 0.43, 0.52, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.63 (± 0.03)       [0.61, 0.65, 0.67, 0.6]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.1 | 2 | 0.2
# ================================================================================
# test_balanced_acc              0.81 (± 0.01)       [0.8, 0.83, 0.82, 0.8]
# test_mcc                       0.47 (± 0.04)       [0.53, 0.45, 0.49, 0.42]
# --------------------------------------------------------------------------------
# Training MCC:                  0.62 (± 0.03)       [0.59, 0.64, 0.66, 0.6]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.2 | 1 | 0.2
# ================================================================================
# test_balanced_acc              0.80 (± 0.01)       [0.78, 0.81, 0.8, 0.78]
# test_mcc                       0.51 (± 0.05)       [0.58, 0.46, 0.53, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.68 (± 0.03)       [0.65, 0.71, 0.71, 0.66]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.2 | 1.25 | 0.25
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.78, 0.81, 0.82, 0.78]
# test_mcc                       0.50 (± 0.05)       [0.56, 0.46, 0.52, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.66 (± 0.03)       [0.63, 0.69, 0.69, 0.64]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.2 | 1.5 | 0.30000000000000004
# ================================================================================
# test_balanced_acc              0.80 (± 0.02)       [0.78, 0.81, 0.84, 0.78]
# test_mcc                       0.49 (± 0.05)       [0.56, 0.45, 0.52, 0.44]
# --------------------------------------------------------------------------------
# Training MCC:                  0.65 (± 0.03)       [0.62, 0.67, 0.68, 0.62]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.2 | 1.75 | 0.35000000000000003
# ================================================================================
# test_balanced_acc              0.80 (± 0.01)       [0.78, 0.81, 0.82, 0.8]
# test_mcc                       0.49 (± 0.04)       [0.55, 0.45, 0.51, 0.46]
# --------------------------------------------------------------------------------
# Training MCC:                  0.64 (± 0.04)       [0.61, 0.67, 0.69, 0.6]
#
# ================================================================================
# SVMSMOTE | RandomUnderSampler | 0.2 | 2 | 0.4
# ================================================================================
# test_balanced_acc              0.81 (± 0.02)       [0.78, 0.83, 0.82, 0.8]
# test_mcc                       0.49 (± 0.04)       [0.56, 0.46, 0.5, 0.45]
# --------------------------------------------------------------------------------
# Training MCC:                  0.63 (± 0.02)       [0.6, 0.65, 0.65, 0.61]
#
# test_balanced_acc              0.74 (± 0.01)       [0.73, 0.75, 0.76, 0.73]
# test_mcc                       0.51 (± 0.06)       [0.6, 0.42, 0.51, 0.5]
# --------------------------------------------------------------------------------
# Training MCC:                  0.82 (± 0.02)       [0.8, 0.85, 0.85, 0.81]

# %%
results = results.dropna(axis=0)

results.sort_values("val_mcc", ascending=False)
# Out:
#    seed upsampler         downsampler up_class_ratio down_vs_up_ratio  \
# 60    1  SVMSMOTE  RandomUnderSampler           0.01                1
# 61    1  SVMSMOTE  RandomUnderSampler           0.01             1.25
# 21    1     SMOTE  RandomUnderSampler           0.01             1.25
# 20    1     SMOTE  RandomUnderSampler           0.01                1
# 65    1  SVMSMOTE  RandomUnderSampler           0.05                1
# ..  ...       ...                 ...            ...              ...
# 58    1    ADASYN  RandomUnderSampler            0.2             1.75
# 56    1    ADASYN  RandomUnderSampler            0.2             1.25
# 59    1    ADASYN  RandomUnderSampler            0.2                2
# 55    1    ADASYN  RandomUnderSampler            0.2                1
# 54    1    ADASYN  RandomUnderSampler            0.1                2
#
#    final_class_ratio train_mcc   val_mcc train_bal_acc val_bal_acc
# 60              0.01  0.797386  0.528798      0.998602    0.775316
# 61            0.0125  0.779014  0.518783      0.998414    0.783314
# 21            0.0125  0.785985  0.514576      0.998495    0.774926
# 20              0.01  0.801048  0.513831      0.998643    0.762682
# 65              0.05  0.698824  0.509715      0.944499    0.795491
# ..               ...       ...       ...           ...         ...
# 58              0.35   0.57735  0.402969      0.988413    0.829107
# 56              0.25  0.584662  0.398823      0.988573    0.812804
# 59               0.4  0.568799  0.397877      0.988232    0.820835
# 55               0.2  0.600348  0.397699         0.993    0.808758
# 54               0.2  0.575723  0.396759      0.991087    0.816869
#
# [78 rows x 10 columns]

# %%
results.to_csv(f"/kaggle/working/results_resampling.csv")
